# %%
# importing the libraries
import numpy as np
import pandas as pd
# from numpy import math
import matplotlib.pyplot as plt
import seaborn as sns
#librabries to check accuracy level
from sklearn.metrics import accuracy_score

# %%
# importing the dataset
dataset = pd.read_csv('C:/Users/49176/Desktop/CDAP/2022-012/Sinhala_Spelling_and_Grammar_Checker/grammar_analysis/Grammar_rules.csv')
print(dataset)
# Out:
#          subject    tense  person   gender     animate number active  \
# 0     3rd_person  වර්තමාන  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 1     3rd_person    අනාගත  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 2     3rd_person  වර්තමාන  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 3     3rd_person    අනාගත  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 4     3rd_person  වර්තමාන  ප්‍රථම    නොමැත  ප්‍රාණවාචි    බහු      y
# ...          ...      ...     ...      ...         ...    ...    ...
# 3032         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3033         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3034         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3035         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3036         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
#
#      honorific  pattern verb_root  ...  Unnamed: 13  Unnamed: 14 Unnamed: 15  \
# ...

# %%
# getting the legth of the dataset
len(dataset)
# Out:
# 3037

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3037 entries, 0 to 3036
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   subject      3037 non-null   object
#  1   tense        3037 non-null   object
#  2   person       3037 non-null   object
#  3   gender       3037 non-null   object
#  4   animate      3037 non-null   object
#  5   number       3037 non-null   object
#  6   active       3037 non-null   object
#  7   honorific    3037 non-null   object
#  8   pattern      3037 non-null   int64
#  9   verb_root    3037 non-null   object
#  10  is_correct   3037 non-null   int64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  17 non-null     object
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
dataset.head()
# Out:
#       subject    tense  person   gender     animate number active honorific  \
# 0  3rd_person  වර්තමාන  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y         y
# 1  3rd_person    අනාගත  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y         y
# 2  3rd_person  වර්තමාන  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y         y
# 3  3rd_person    අනාගත  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y         y
# 4  3rd_person  වර්තමාන  ප්‍රථම    නොමැත  ප්‍රාණවාචි    බහු      y         n
#
#    pattern verb_root  ...  Unnamed: 13  Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 0        1       අති  ...          NaN          NaN         NaN          NaN
# 1        1       අති  ...          NaN          NaN         NaN          NaN
# 2        1       අති  ...          NaN          NaN         NaN          NaN
# 3        1       අති  ...          NaN          NaN         NaN          NaN
# 4        1       අති  ...          NaN          NaN         NaN          NaN
#
# ...

# %%
df = dataset.loc[:, ~dataset.columns.str.contains('^Unnamed')]
print(df)
# Out:
#          subject    tense  person   gender     animate number active  \
# 0     3rd_person  වර්තමාන  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 1     3rd_person    අනාගත  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 2     3rd_person  වර්තමාන  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 3     3rd_person    අනාගත  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 4     3rd_person  වර්තමාන  ප්‍රථම    නොමැත  ප්‍රාණවාචි    බහු      y
# ...          ...      ...     ...      ...         ...    ...    ...
# 3032         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3033         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3034         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3035         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3036         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
#
#      honorific  pattern verb_root  is_correct
# 0            y        1       අති           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3037 entries, 0 to 3036
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   subject     3037 non-null   object
#  1   tense       3037 non-null   object
#  2   person      3037 non-null   object
#  3   gender      3037 non-null   object
#  4   animate     3037 non-null   object
#  5   number      3037 non-null   object
#  6   active      3037 non-null   object
#  7   honorific   3037 non-null   object
#  8   pattern     3037 non-null   int64
#  9   verb_root   3037 non-null   object
#  10  is_correct  3037 non-null   int64
# dtypes: int64(2), object(9)
# memory usage: 261.1+ KB

# %%
df.describe()
# Out:
#            pattern   is_correct
# count  3037.000000  3037.000000
# mean      1.207442     0.043135
# std       0.664186     0.203194
# min       1.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     0.000000
# 75%       1.000000     0.000000
# max       4.000000     1.000000

# %%
# Display all the column names 
for col in df.columns:
    print(col)
# Out:
# subject
# tense
# person
# gender
# animate
# number
# active
# honorific
# pattern
# verb_root
# is_correct

# %%
df.head()
# Out:
#       subject    tense  person   gender     animate number active honorific  \
# 0  3rd_person  වර්තමාන  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y         y
# 1  3rd_person    අනාගත  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y         y
# 2  3rd_person  වර්තමාන  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y         y
# 3  3rd_person    අනාගත  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y         y
# 4  3rd_person  වර්තමාන  ප්‍රථම    නොමැත  ප්‍රාණවාචි    බහු      y         n
#
#    pattern verb_root  is_correct
# 0        1       අති           1
# 1        1       අති           1
# 2        1       අති           1
# 3        1       අති           1
# 4        1       අති           1

# %%
print(df)
# Out:
#          subject    tense  person   gender     animate number active  \
# 0     3rd_person  වර්තමාන  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 1     3rd_person    අනාගත  ප්‍රථම  ස්ත්‍රී  ප්‍රාණවාචි    බහු      y
# 2     3rd_person  වර්තමාන  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 3     3rd_person    අනාගත  ප්‍රථම    පුරුෂ  ප්‍රාණවාචි    බහු      y
# 4     3rd_person  වර්තමාන  ප්‍රථම    නොමැත  ප්‍රාණවාචි    බහු      y
# ...          ...      ...     ...      ...         ...    ...    ...
# 3032         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3033         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3034         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3035         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
# 3036         ඔබ     අනාගත  මධ්‍යම    නොමැත  ප්‍රාණවාචි     ඒක      y
#
#      honorific  pattern verb_root  is_correct
# 0            y        1       අති           1
# ...
